# %% [markdown]
# a) Start with reading in the dataset into a dataframe using pandas.

# %%
import pandas as pd

df_os = pd.read_csv("data/athlete_events.csv")
df_os
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
import duckdb


duckdb.query("SELECT * FROM df_os").df()
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# c) Use pandas columns method to find out the columns

# %%
df_os.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
#   d) Find out the 10 oldest atheletes, their age and the sport

# %%
duckdb.query("SELECT NAME, AGE, SPORT FROM df_os ORDER BY AGE DESC LIMIT 10").df()
# Out:
#                          Name   Age             Sport
# 0      John Quincy Adams Ward  97.0  Art Competitions
# 1               Winslow Homer  96.0  Art Competitions
# 2  Thomas Cowperthwait Eakins  88.0  Art Competitions
# 3  Thomas Cowperthwait Eakins  88.0  Art Competitions
# 4  Thomas Cowperthwait Eakins  88.0  Art Competitions
# 5       George Denholm Armour  84.0  Art Competitions
# 6                Louis Tauzin  81.0  Art Competitions
# 7        Robert Tait McKenzie  81.0  Art Competitions
# 8              Max Liebermann  80.0  Art Competitions
# 9              Max Liebermann  80.0  Art Competitions

# %% [markdown]
# e) Find out the 10 youngest atheletes, their age and the sport

# %%
duckdb.query("SELECT NAME, AGE, SPORT, YEAR, MEDAL FROM df_os ORDER BY AGE LIMIT 10").df()
# Out:
#                                               Name   Age           Sport  \
# 0                               Dimitrios Loundras  10.0      Gymnastics
# 1  Megan Olwen Devenish Taylor (-Mandeville-Ellis)  11.0  Figure Skating
# 2                                     Liana Vicens  11.0        Swimming
# 3                                     Liana Vicens  11.0        Swimming
# 4                                     Liana Vicens  11.0        Swimming
# 5                                     Liana Vicens  11.0        Swimming
# 6                                     Etsuko Inada  11.0  Figure Skating
# 7                                       Liu Luyang  11.0  Figure Skating
# 8                                Marcelle Matthews  11.0  Figure Skating
# 9                       Magdalena Cecilia Colledge  11.0  Figure Skating
#
#    Year   Medal
# 0  1896  Bronze
# 1  1932    None
# 2  1968    None
# 3  1968    None
# 4  1968    None
# 5  1968    None
# 6  1936    None
# 7  1988    None
# ...

# %% [markdown]
#   e) Find out the five sports with highest median age

# %%
duckdb.query("""SELECT 
             SPORT, MEDIAN(AGE) as median_age 
             FROM df_os GROUP BY SPORT 
             ORDER BY median_age DESC 
             LIMIT 5""").df()
# Out:
#               Sport  median_age
# 0             Roque        59.0
# 1  Art Competitions        45.0
# 2          Alpinism        38.0
# 3              Polo        35.0
# 4     Equestrianism        33.0

# %%
df_os.groupby("Sport")[["Sport", "Age"]].median(numeric_only=True).sort_values(
    by="Age", ascending=False
).head().reset_index().rename({"Age": "median_age"}, axis=1)
# Out:
#               Sport  median_age
# 0             Roque        59.0
# 1  Art Competitions        45.0
# 2          Alpinism        38.0
# 3              Polo        35.0
# 4     Equestrianism        33.0

# %% [markdown]
#  f) Find out the five sports with lowest median age

# %%
duckdb.query("SELECT SPORT, MEDIAN(AGE) as median_age FROM df_os GROUP BY SPORT ORDER BY median_age LIMIT 5").df()
# Out:
#                    Sport  median_age
# 0    Rhythmic Gymnastics        18.0
# 1               Swimming        20.0
# 2  Synchronized Swimming        22.0
# 3         Figure Skating        22.0
# 4             Gymnastics        22.0

# %% [markdown]
#   f) Find out top 10 countries after number of gold medals

# %%
duckdb.query("SELECT NOC, COUNT(MEDAL) as num_medals  FROM df_os WHERE MEDAL = 'Gold' GROUP BY NOC ORDER BY num_medals DESC LIMIT 10").df()
# Out:
#    NOC  num_medals
# 0  USA        2638
# 1  URS        1082
# 2  GER         745
# 3  GBR         678
# 4  ITA         575
# 5  FRA         501
# 6  SWE         479
# 7  CAN         463
# 8  HUN         432
# 9  GDR         397

# %% [markdown]
#  g) Find out top 10 countries after number of medals

# %%
duckdb.query("SELECT NOC, COUNT(MEDAL) as num_medals  FROM df_os GROUP BY NOC ORDER BY num_medals DESC LIMIT 10").df()
# Out:
#    NOC  num_medals
# 0  USA        5637
# 1  URS        2503
# 2  GER        2165
# 3  GBR        2068
# 4  FRA        1777
# 5  ITA        1637
# 6  SWE        1536
# 7  CAN        1352
# 8  AUS        1320
# 9  RUS        1165

# %% [markdown]
#   h) Plot a time series line chart of number of female and male atheletes in same graph.

# %%
df_os.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
import seaborn as sns

# %%
male_female = duckdb.query(
    """SELECT 
        YEAR, 
        SEX, 
        COUNT(SEX) as Total 
    FROM df_os 
    GROUP BY YEAR, SEX 
    ORDER BY YEAR"""
).df()
male_female
# Out:
#     Year Sex  Total
# 0   1896   M    380
# 1   1900   M   1903
# 2   1900   F     33
# 3   1904   M   1285
# 4   1904   F     16
# ..   ...  ..    ...
# 64  2012   F   5815
# 65  2014   F   2023
# 66  2014   M   2868
# 67  2016   M   7465
# 68  2016   F   6223
#
# [69 rows x 3 columns]

# %%
sns.lineplot(male_female, x="Year", y="Total", hue="Sex")
# Out:
# <Axes: xlabel='Year', ylabel='Total'>

# %%
male_female
# Out:
#     Year Sex  Total
# 0   1896   M    380
# 1   1900   M   1903
# 2   1900   F     33
# 3   1904   M   1285
# 4   1904   F     16
# ..   ...  ..    ...
# 64  2012   F   5815
# 65  2014   F   2023
# 66  2014   M   2868
# 67  2016   M   7465
# 68  2016   F   6223
#
# [69 rows x 3 columns]
