# %% [markdown]
# # 0. Working with national test data
# Skolverket is a school authority in Sweden that has collected lots of data for schools in Sweden. We'll analyze national tests results. Data is found in this repository here.
#
#   a) Start with reading in the file riket2023_åk9_np.xlsx and the sheets for the different subjects.
#
#   b) Change the column names to get something similar to this:

# %%
import pandas as pd

df_engelska = pd.read_excel("data/riket2023_åk9_np.xlsx", sheet_name="Engelska")
df_engelska
# Out:
#                                            Unnamed: 0       Unnamed: 1  \
# 0                                                 NaN              NaN
# 1   Grundskolan - Resultat nationella prov årskurs...              NaN
# 2                                            Engelska              NaN
# 3                                 Valt läsår: 2022/23              NaN
# 4                                                 NaN              NaN
# 5                                                 NaN              NaN
# 6                                                 NaN              NaN
# 7                                               Riket  Typ av huvudman
# 8                                               Riket         Samtliga
# 9                                               Riket         Kommunal
# 10                                              Riket          Enskild
# 11                                              Riket       Skolverket
#
# ...

# %%
import pandas as pd

df_engelska = pd.read_excel("data/riket2023_åk9_np.xlsx", sheet_name="Engelska")
df_engelska.tail(4)

df_svenska = pd.read_excel("Data/riket2023_åk9_np.xlsx", sheet_name = "Svenska")
df_svenska = df_svenska.tail(4).reset_index().drop(columns="index")

df_matematik = pd.read_excel("Data/riket2023_åk9_np.xlsx", sheet_name = "Matematik")
df_matematik = df_matematik.tail(4).reset_index().drop(columns="index")
 
 

df_engelska.columns

df_engelska = df_engelska.tail(4).reset_index().drop(columns="index")
df_engelska
df_engelska_cleaned = df_engelska.rename(
    {
        "Unnamed: 0": "Plats",
        "Unnamed: 1": "Huvudman",
        "Unnamed: 2": "Totalt (A-F)",
        "Unnamed: 3": "Flickor (A-F)",
        "Unnamed: 4": "Pojkar (A-F)",
        "Unnamed: 5": "Totalt (A-E)",
        "Unnamed: 6": "Flickor (A-E)",
        "Unnamed: 7": "Pojkar (A-E)",
        "Unnamed: 8": "Totalt (poäng)",
        "Unnamed: 9": "Flickor (poäng)",
        "Unnamed: 10": "Pojkar (poäng)",
    },
    axis=1,
)

df_svenska_cleaned = df_svenska.rename({"Unnamed: 0": "Plats",
                    "Unnamed: 1": "Huvudman",
                    "Unnamed: 2": "Toalt (A-F)",
                    "Unnamed: 3": "Flickor (A-F)",
                    "Unnamed: 4": "Pojkar (A-F)",
                    "Unnamed: 5": "Totalt (A-E)",
                    "Unnamed: 6": "Flickor (A-E)",
                    "Unnamed: 7": "Pojkar (A-E)",
                    "Unnamed: 8": "Totalt (poäng)",
                    "Unnamed: 9": "Flickor (poäng)",
                    "Unnamed: 10": "Pojkar (poäng)"
}, axis=1)

df_matematik_cleaned = df_matematik.rename({"Unnamed: 0": "Plats",
                    "Unnamed: 1": "Huvudman",
                    "Unnamed: 2": "Toalt (A-F)",
                    "Unnamed: 3": "Flickor (A-F)",
                    "Unnamed: 4": "Pojkar (A-F)",
                    "Unnamed: 5": "Totalt (A-E)",
                    "Unnamed: 6": "Flickor (A-E)",
                    "Unnamed: 7": "Pojkar (A-E)",
                    "Unnamed: 8": "Totalt (poäng)",
                    "Unnamed: 9": "Flickor (poäng)",
                    "Unnamed: 10": "Pojkar (poäng)"
}, axis=1)
 


 

df_engelska_cleaned
df_svenska_cleaned
df_matematik_cleaned
# Out:
#    Plats    Huvudman Toalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 0  Riket    Samtliga      106766         51548        55218         89.1
# 1  Riket    Kommunal       84163         40386        43777         88.1
# 2  Riket     Enskild       22553         11137        11416         92.9
# 3  Riket  Skolverket          50            25           25         ~100
#
#   Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (poäng) Pojkar (poäng)
# 0          88.7         89.5           11.9            11.8             12
# 1          87.7         88.5           11.6            11.5           11.7
# 2          92.2         93.5             13            12.8           13.1
# 3          ~100         ~100           14.1            13.5           14.7

# %% [markdown]
#   c) Do some initial exploratory data analysis on this dataset. Use methods such as info, value_counts, columns, describe and some more to get a first insight into the dataset.
#
#   d) Find out the amount of students that got F in mathematics (both girls and boys).
#
#   e) Draw a bar chart on the total points for each of the subjects
#
#   f) Feel free to do more EDA on this dataset

# %%
df_engelska_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plats            4 non-null      object
#  1   Huvudman         4 non-null      object
#  2   Totalt (A-F)     4 non-null      object
#  3   Pojkar (A-F)     4 non-null      object
#  4   Pojkar (A-F)     4 non-null      object
#  5   Totalt (A-E)     4 non-null      object
#  6   Flickor (A-E)    4 non-null      object
#  7   Pojkar (A-E)     4 non-null      object
#  8   Totalt (poäng)   4 non-null      object
#  9   Flickor (poäng)  4 non-null      object
#  10  Pojkar (poäng)   4 non-null      object
# dtypes: object(11)
# memory usage: 484.0+ bytes

# %%
#df_cleaned_names["Calories"] = df_cleaned_names["Calories"].str[:-3].astype(int)

df_engelska_cleaned["Totalt (A-F)"] = df_engelska_cleaned["Totalt (A-F)"].astype(int)
df_engelska_cleaned["Totalt (A-E)"] = df_engelska_cleaned["Totalt (A-E)"].astype(float)

df_engelska_cleaned.info()

passed = df_engelska_cleaned["Totalt (A-F)"] *( df_engelska_cleaned["Totalt (A-E)"] / 100)
failed = df_engelska_cleaned["Totalt (A-F)"] - passed
failed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plats            4 non-null      object
#  1   Huvudman         4 non-null      object
#  2   Totalt (A-F)     4 non-null      int64
#  3   Pojkar (A-F)     4 non-null      object
#  4   Pojkar (A-F)     4 non-null      object
#  5   Totalt (A-E)     4 non-null      float64
#  6   Flickor (A-E)    4 non-null      object
#  7   Pojkar (A-E)     4 non-null      object
#  8   Totalt (poäng)   4 non-null      object
#  9   Flickor (poäng)  4 non-null      object
#  10  Pojkar (poäng)   4 non-null      object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 484.0+ bytes
# 0    3208.230
# 1    2866.540
# 2     293.566
# 3       0.000
# dtype: float64

# %%
df_dict = {}
for subject in ["Engelska", "Matematik", "Svenska", "Svenska som andraspråk"]:
    df_dict[subject] = pd.read_excel("data/riket2023_åk9_np.xlsx", sheet_name=subject)

df_dict["Matematik"].tail(4)
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 8       Riket    Samtliga     106766      51548      55218       89.1
# 9       Riket    Kommunal      84163      40386      43777       88.1
# 10      Riket     Enskild      22553      11137      11416       92.9
# 11      Riket  Skolverket         50         25         25       ~100
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 8        88.7       89.5       11.9       11.8          12
# 9        87.7       88.5       11.6       11.5        11.7
# 10       92.2       93.5         13       12.8        13.1
# 11       ~100       ~100       14.1       13.5        14.7

# %%
df_engelska_cleaned
# Out:
#    Plats    Huvudman  Totalt (A-F) Pojkar (A-F) Pojkar (A-F)  Totalt (A-E)  \
# 0  Riket    Samtliga        106941        51864        55077          97.0
# 1  Riket    Kommunal         84310        40675        43635          96.6
# 2  Riket     Enskild         22582        11165        11417          98.7
# 3  Riket  Skolverket            49           24           25         100.0
#
#   Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (poäng) Pojkar (poäng)
# 0          97.1           97           15.7            15.8           15.7
# 1          96.6         96.6           15.4            15.5           15.4
# 2          98.8         98.7           16.9              17           16.8
# 3           100          100           18.5            18.9           18.2

# %%
df_engelska_cleaned[df_engelska_cleaned["Huvudman"] == "Samtliga"]["Totalt (poäng)"]
# Out:
# 0    15.7
# Name: Totalt (poäng), dtype: object

# %%
df_engelska_cleaned.columns
# Out:
# Index(['Plats', 'Huvudman', 'Totalt (A-F)', 'Pojkar (A-F)', 'Pojkar (A-F)',
#        'Totalt (A-E)', 'Flickor (A-E)', 'Pojkar (A-E)', 'Totalt (poäng)',
#        'Flickor (poäng)', 'Pojkar (poäng)'],
#       dtype='object')

# %%
eng_points = df_engelska_cleaned.query("Huvudman == 'Samtliga'")["Totalt (poäng)"]
eng_points
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 eng_points = df_engelska_cleaned.query("Huvudman == 'Samtliga'")["Totalt (poäng)"]
#       2 eng_points
#
# File ~/Documents/github/data-platform-henrik-sjogren-de24/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File ~/Documents/github/data-platform-henrik-sjogren-de24/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4943, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4941 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4942 index_resolvers = self._get_index_resolvers()
# -> 4943 column_resolvers = self._get_cleaned_column_resolvers()
# ...

# %%
import seaborn as sns

# betyg_poäng = {
#         "Svenska": df_svenska_cleaned.query("Huvudman == 'Samtliga'")["Totalt (poäng)"],
#         "Engelska": df_engelska_cleaned.query("Huvudman == 'Samtliga'")["Totalt (poäng)"],
#         "Matematik": df_matematik_cleaned.query("Huvudman == 'Samtliga'")["Totalt (poäng)"]
# }
# sns.barplot(betyg_poäng)

eng_points = df_engelska_cleaned.query("`Huvudman` == 'Samtliga'")["Totalt (poäng)"]
ma_points = df_matematik_cleaned.query("`Huvudman` == 'Samtliga'")["Totalt (poäng)"]
sv_points = df_svenska_cleaned.query("`Huvudman` == 'Samtliga'")["Totalt (poäng)"]
data_frame = {
    "ENG": eng_points,
    "MA": ma_points,
    "SV": sv_points
}
 
sns.barplot(data_frame)
# Out:
# <Axes: >
